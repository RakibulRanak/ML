# %%
import seaborn as sns
iris = sns.load_dataset('iris')
print(iris.sepal_length[iris.species=='setosa'])
print(max(iris.sepal_length[iris.species=='setosa']))
correlation = iris.corr()
sns.heatmap(iris.corr(), cmap = 'coolwarm',  annot=True)
# Out:
# 0     5.1
# 1     4.9
# 2     4.7
# 3     4.6
# 4     5.0
# 5     5.4
# 6     4.6
# 7     5.0
# 8     4.4
# 9     4.9
# 10    5.4
# 11    4.8
# 12    4.8
# 13    4.3
# 14    5.8
# 15    5.7
# 16    5.4
# 17    5.1
# 18    5.7
# 19    5.1
# 20    5.4
# 21    5.1
# 22    4.6
# 23    5.1
# 24    4.8
# 25    5.0
# 26    5.0
# 27    5.2
# 28    5.2
# 29    4.7
# 30    4.8
# 31    5.4
# 32    5.2
# 33    5.5
# 34    4.9
# 35    5.0
# 36    5.5
# 37    4.9
# 38    4.4
# 39    5.1
# 40    5.0
# 41    4.5
# 42    4.4
# 43    5.0
# 44    5.1
# 45    4.8
# 46    5.1
# 47    4.6
# 48    5.3
# 49    5.0
# Name: sepal_length, dtype: float64
# 5.8

# %%
sns.set(style="whitegrid", color_codes=True) # change style
sns.lmplot(x="sepal_length", y="petal_length", hue="species", data = iris, \
              palette="Set1", markers=["o", "s", "D"])

# %%
sns.pairplot(iris,
             markers=["o", "s", "D"], hue="species")

# %%
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]
sns.lmplot(x="ID", y="ratio", data=iris, \
           hue="species", markers=["o", "s", "D"], fit_reg=False, legend=True)
# Out:
# RangeIndex(start=0, stop=150, step=1)
