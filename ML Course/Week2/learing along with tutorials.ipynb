# %%
import turicreate as tc
sales = tc.SFrame('home_data.sframe/')

# %%
sales.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
tc.visualization.scatter(sales['sqft_living'],sales['price'])
# Out:
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 
# ...

# %%
import pandas as pd
data = sales.to_dataframe()
data.head()
# Out:
#            id                       date     price  bedrooms  bathrooms  \
# 0  7129300520  2014-10-13 00:00:00+00:00  221900.0       3.0       1.00
# 1  6414100192  2014-12-09 00:00:00+00:00  538000.0       3.0       2.25
# 2  5631500400  2015-02-25 00:00:00+00:00  180000.0       2.0       1.00
# 3  2487200875  2014-12-09 00:00:00+00:00  604000.0       4.0       3.00
# 4  1954400510  2015-02-18 00:00:00+00:00  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0       1180.0    5650.0     1.0           0     0  ...    7.0      1180.0
# 1       2570.0    7242.0     2.0           0     0  ...    7.0      2170.0
# 2        770.0   10000.0     1.0           0     0  ...    6.0       770.0
# 3       1960.0    5000.0     1.0           0     0  ...    7.0      1050.0
# 4       1680.0    8080.0     1.0           0     0  ...    8.0      1680.0
#
#    sqft_basement  yr_built  yr_renovated  zipcode        lat        long  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  object
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  float64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  float64
#  6   sqft_lot       21613 non-null  float64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  float64
#  12  sqft_above     21613 non-null  float64
#  13  sqft_basement  21613 non-null  float64
#  14  yr_built       21613 non-null  float64
#  15  yr_renovated   21613 non-null  float64
#  16  zipcode        21613 non-null  object
# ...

# %%
from sklearn.model_selection import train_test_split
#import copy
#from sklearn.metrics import accuracy_score
X = data.copy()
y = X.pop('price')
X.pop('date')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=4,test_size=0.33)

# %%
X.shape
# Out:
# (21613, 19)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import numpy as np
k_fold = KFold(n_splits=11, shuffle=True, random_state=0)
clf = RandomForestRegressor(max_depth=35,n_estimators=9)
scoring = 'neg_mean_squared_error'
X = X['sqft_living']
print(X.shape)
X = X.values.reshape(-1,1)
print(X.shape)
score = cross_val_score(clf, X,np.log(y) , cv=k_fold, n_jobs=1, scoring=scoring)
score = -1 * score.mean()
score
# Out:
# (21613,)
# (21613, 1)
# 0.14640666647303238

# %%
y.shape
# Out:
# (21613,)

# %%
# from sklearn.linear_model import LinearRegression
# clf = LinearRegression()
# score = cross_val_score(clf, X,y , cv=k_fold, n_jobs=1, scoring=scoring)
# score

# %%
data
# Out:
#                id                       date     price  bedrooms  bathrooms  \
# 0      7129300520  2014-10-13 00:00:00+00:00  221900.0       3.0       1.00
# 1      6414100192  2014-12-09 00:00:00+00:00  538000.0       3.0       2.25
# 2      5631500400  2015-02-25 00:00:00+00:00  180000.0       2.0       1.00
# 3      2487200875  2014-12-09 00:00:00+00:00  604000.0       4.0       3.00
# 4      1954400510  2015-02-18 00:00:00+00:00  510000.0       3.0       2.00
# ...           ...                        ...       ...       ...        ...
# 21608  0263000018  2014-05-21 00:00:00+00:00  360000.0       3.0       2.50
# 21609  6600060120  2015-02-23 00:00:00+00:00  400000.0       4.0       2.50
# 21610  1523300141  2014-06-23 00:00:00+00:00  402101.0       2.0       0.75
# 21611  0291310100  2015-01-16 00:00:00+00:00  400000.0       3.0       2.50
# 21612  1523300157  2014-10-15 00:00:00+00:00  325000.0       2.0       0.75
#
# ...

# %%
clf.fit(X,np.log(y))
np.exp(clf.predict([[2310]]))
# Out:
# array([538571.65113049])
